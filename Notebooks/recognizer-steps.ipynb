# %% [markdown]
# Recognizer Steps=================Here is a demonstration of the different steps of the recognizer.This worksheet may also be useful for debugging the recognizer or segmenter.

# %% [markdown]
# We add ".." to the search path so that we get the `ocrolib` directory we are working in.

# %%
sys.path = [".."]+sys.path

# %%
from pylab import *import ocrolib; reload(ocrolib)from ocrolib import morph; reload(morph)from ocrolib import lineseg; reload(lineseg)from ocrolib import lineproc; reload(lineproc)from ocrolib import segrec; reload(segrec)from collections import Counterfrom scipy.ndimage import measurements

# %% [markdown]
# Loading the Image=================

# %% [markdown]
# Select the input image here.

# %%
#fname = "010023.png"fname = "010052.png"

# %% [markdown]
# Let's read the input image.

# %%
image = ocrolib.read_image_gray(fname)figsize(18,6); gray()imshow(image)

# %% [markdown]
# Input images to the line segmenter should be black-on-white and only contain components from a single line.The x-height should be somewhere between 15 and 30 pixels.  The line recognizers will check whether line height and other aspects of the image are reasonable and otherwiserefuse to recognize the line (this can be overridden).The line recognizer will also attempt to remove noise from the input.

# %% [markdown]
# The Segmenter=================

# %% [markdown]
# Let's run the segmenter, just to see how well it is working by itself.

# %%
reload(lineseg)segmenter = lineseg.DPSegmentLine()seg = segmenter.charseg(image)morph.showlabels(seg)

# %% [markdown]
# The Character Recognizer========================

# %% [markdown]
# Now we load the character recognition model.

# %%
if "cmodel" not in dir():    cmodel = ocrolib.load_component(ocrolib.ocropus_find_file("st1m.cmodel"))

# %% [markdown]
# We can actually run the character recognizer on a single character image.  Here is an example of that.Note that inputs to the character recognizer are white-on-black.

# %%
from llpy import csclass; reload(csclass)figsize(3,3)cimage = (seg==1)[:,:50]imshow(cimage)cmodel.coutputs(cimage)
# Out:
# [(u'i', 0.98530625795038718), (u'~', 0.010571047764459605)]

# %% [markdown]
# The Line Recognizer====================

# %% [markdown]
# Here we construct the line recognizer from the segmenter and the character model.There is also a space model.

# %%
linerec = ocrolib.CmodelLineRecognizer(cmodel=cmodel,whitespace="space.model",                                       maxrange=4,verbose=1,debug_cls=None,                                       segmenter=segmenter)linerec.use_ligatures = 0linerec.maxcost = 10.0linerec.nbest = 3linerec.display = 0linerec.norejects = 1

# %% [markdown]
# Now let's run the line recognizer.

# %%
figsize(16,16)linerec.recognize(image)print linerec.bestpath()imshow(linerec.image,interpolation='nearest')
# Out:
# infomation. There is a comprehensive bibliography classif1ed

# %% [markdown]
# Let's look at the output from the line segmenter that the recognizer was actually using.

# %%
figsize(16,16)morph.showlabels(linerec.rseg)

# %% [markdown]
# And here we can see the individual characters and their associated outputs.The special class "~" means a reject.The values here are _costs_, i.e., negative log probabilities (the `coutputs` method forthe cmodel recognizer outputs posterior probabilities.)

# %%
figsize(16,24)for i,c in enumerate(linerec.chars[:256]):    subplot(16,16,i+1)    xticks([]); yticks([])    xlabel("%s %.1f"%(c.outputs[0]))    imshow(c.image,interpolation='nearest')
